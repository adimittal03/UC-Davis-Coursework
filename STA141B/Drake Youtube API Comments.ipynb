# %%
#For God's Plan

# %%
from googleapiclient.discovery import build
from collections import defaultdict
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
api_key = "AIzaSyCKhyPTPEHgjrobMjxXQOAq-Q-X5YyKRfc"
video_id = "xpVfcZ0ZcFM"  #extracting from God's Plan
#build a resource for youtube ??
resource = build('youtube', 'v3', developerKey=api_key)

#create a request to get 100 comments on the video
request = resource. commentThreads().list(
                            part="snippet",
                            videoId=video_id,
                            maxResults= 100,
                            order="orderUnspecified") #top comments

#execute the request
response = request.execute()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from googleapiclient.discovery import build
#       2 from collections import defaultdict
#       3 import json
#
# ModuleNotFoundError: No module named 'googleapiclient'

# %%
response.keys()
# Out:
# dict_keys(['kind', 'etag', 'nextPageToken', 'pageInfo', 'items'])

# %%
items = response['items'][:99]
items
df=pd.json_normalize(items)
df=df['snippet.topLevelComment.snippet.textDisplay']
df.head()
# Out:
# 0                              still listening in 2030
# 1                                      I love this!!!!
# 2                                           Disgusting
# 3    in this day and age drake would be cancelled f...
# 4                                   Who’s here in 2023
# Name: snippet.topLevelComment.snippet.textDisplay, dtype: object

# %%
text = df.to_csv() #converting the data frame to text file 
# in order to generate to a word cloud of a shape in python

# %%
import nltk
from nltk import tokenize
words = tokenize.word_tokenize(text)
words = [w for w in words if w.isalpha()] #assures only words are in the output 
#words=[x.lower() for x in words] #lower-casing the words as well

# %%
#Removing stopwords 
stopwords = ["the", "a", "and", "or", "in"]
final_words = [w for w in words if w not in stopwords]

# %%
type(final_words)
# Out:
# list

# %%
text = ' '.join(final_words) #turning list back into string
type(text)
# Out:
# str

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import numpy as np
from PIL import Image

# %%
stopwords = set(STOPWORDS)
cloud = np.array(Image.open("cloud.png"))
# Create a word cloud image
wc = WordCloud(background_color="black", max_words=1000, mask=cloud,
               contour_width=3, contour_color='firebrick')

# Generate a wordcloud
wc.generate(text)

# store to file

# show
plt.figure(figsize=[20,10])
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# Extracting from Nice For What

# %%
api_key = "AIzaSyCKhyPTPEHgjrobMjxXQOAq-Q-X5YyKRfc"
video_id = "U9BwWKXjVaI"  #extracting from Nice For What 
#build a resource for youtube ??
resource = build('youtube', 'v3', developerKey=api_key)

#create a request to get 100 comments on the video
request = resource. commentThreads().list(
                            part="snippet",
                            videoId=video_id,
                            maxResults= 100,
                            order="orderUnspecified") #top comments

#execute the request
response = request.execute()
response.keys()
# Out:
# dict_keys(['kind', 'etag', 'nextPageToken', 'pageInfo', 'items'])

# %%
items = response['items'][:99]
items
df=pd.json_normalize(items)
df=df['snippet.topLevelComment.snippet.textDisplay']
df.head()
# Out:
# 0    That&#39;s one ugly city filled with a lot of ...
# 1                                 Staying true to spot
# 2    Lil Wayne is  not umoungst the living  dunno k...
# 3    They only let theses guys blow up. For their c...
# 4    When this came out I was getting crazy money. ...
# Name: snippet.topLevelComment.snippet.textDisplay, dtype: object

# %%
text = df.to_csv() #converting the data frame to text file 
# in order to generate to a word cloud of a shape in python

# %%
import nltk
from nltk import tokenize
words = tokenize.word_tokenize(text)
words = [w for w in words if w.isalpha()] #assures only words are in the output 
#words=[x.lower() for x in words] #lower-casing the words as well

# %%
#Removing stopwords 
stopwords = ["the", "a", "and", "or", "in"]
final_words = [w for w in words if w not in stopwords]

# %%
text = ' '.join(final_words) #turning list back into string
type(text)
# Out:
# str

# %%
stopwords = set(STOPWORDS)
cloud = np.array(Image.open("cloud.png"))
# Create a word cloud image
wc = WordCloud(background_color="black", max_words=1000, mask=cloud,
               contour_width=3, contour_color='firebrick')

# Generate a wordcloud
wc.generate(text)

# store to file

# show
plt.figure(figsize=[20,10])
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# In My Feelings

# %%
api_key = "AIzaSyCKhyPTPEHgjrobMjxXQOAq-Q-X5YyKRfc"
video_id = "DRS_PpOrUZ4"  #extracting from In My Feelings 
#build a resource for youtube ??
resource = build('youtube', 'v3', developerKey=api_key)

#create a request to get 100 comments on the video
request = resource. commentThreads().list(
                            part="snippet",
                            videoId=video_id,
                            maxResults= 100,
                            order="orderUnspecified") #top comments

#execute the request
response = request.execute()
response.keys()
# Out:
# dict_keys(['kind', 'etag', 'nextPageToken', 'pageInfo', 'items'])

# %%
items = response['items'][:99]
items
df=pd.json_normalize(items)
df=df['snippet.topLevelComment.snippet.textDisplay']
df.head()
# Out:
# 0    <a href="https://www.youtube.com/watch?v=DRS_P...
# 1    Video in first is great w granny talk with the...
# 2                              Jhope in Drake&#39;s mv
# 3                            John L Leflore  Boogie C.
# 4                                           Aging well
# Name: snippet.topLevelComment.snippet.textDisplay, dtype: object

# %%
text = df.to_csv() #converting the data frame to text file 
# in order to generate to a word cloud of a shape in python

# %%
import nltk
from nltk import tokenize
words = tokenize.word_tokenize(text)
words = [w for w in words if w.isalpha()] #assures only words are in the output 
#words=[x.lower() for x in words] #lower-casing the words as well

# %%
#Removing stopwords 
stopwords = ["the", "a", "and", "or", "in"]
final_words = [w for w in words if w not in stopwords]

# %%
text = ' '.join(final_words) #turning list back into string
type(text)
# Out:
# str

# %%
stopwords = set(STOPWORDS)
cloud = np.array(Image.open("cloud.png"))
# Create a word cloud image
wc = WordCloud(background_color="black", max_words=1000, mask=cloud,
               contour_width=3, contour_color='firebrick')

# Generate a wordcloud
wc.generate(text)

# store to file

# show
plt.figure(figsize=[20,10])
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# Comments for One Dance, maybe find a better video?
